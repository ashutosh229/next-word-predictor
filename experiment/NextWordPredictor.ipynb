# %% [markdown]
# ## Building the corpus

# %%
import pandas as pd

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d abhinavmoudgil95/short-jokes
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/abhinavmoudgil95/short-jokes
# License(s): DbCL-1.0
# Downloading short-jokes.zip to /content
#   0% 0.00/9.82M [00:00<?, ?B/s]
# 100% 9.82M/9.82M [00:00<00:00, 110MB/s]

# %%
# !unzip short-jokes.zip
# Out:
# Archive:  short-jokes.zip
#   inflating: shortjokes.csv

# %%
df = pd.read_csv("/content/shortjokes.csv",encoding="utf-8")
df = df.drop(columns=["ID"])
df
# Out:
#                                                      Joke
# 0       [me narrating a documentary about narrators] "...
# 1       Telling my daughter garlic is good for you. Go...
# 2       I've been going through a really rough period ...
# 3       If I could have dinner with anyone, dead or al...
# 4          Two guys walk into a bar. The third guy ducks.
# ...                                                   ...
# 231652                The Spicy Sausage by Delia Katessen
# 231653  TIL That I Shouldn't have gone to law school, ...
# 231654  What did the RAM stick say to the politician? ...
# 231655  what do you call a play about victorian era me...
# 231656  Calculus should be taught in every high school...
#
# [231657 rows x 1 columns]

# %%
df2 = df.head(10) #Extracting the first 10 rows for fast computation, due to low amount of data

# %%
df2
# Out:
#                                                 Joke
# 0  [me narrating a documentary about narrators] "...
# 1  Telling my daughter garlic is good for you. Go...
# 2  I've been going through a really rough period ...
# 3  If I could have dinner with anyone, dead or al...
# 4     Two guys walk into a bar. The third guy ducks.
# 5  Why can't Barbie get pregnant? Because Ken com...
# 6   Why was the musician arrested? He got in treble.
# 7  Did you hear about the guy who blew his entire...
# 8  What do you do if a bird shits on your car? Do...
# 9  He was a real gentlemen and always opened the ...

# %%
df2.shape
# Out:
# (10, 1)

# %%
str = ""
rows = df2.shape[0]
for i in range(0,rows):
   str = (str + "\n" + df["Joke"][i])
docs = str

# %%
docs
# Out:
# '\n[me narrating a documentary about narrators] "I can\'t hear what they\'re saying cuz I\'m talking"\nTelling my daughter garlic is good for you. Good immune system and keeps pests away.Ticks, mosquitos, vampires... men.\nI\'ve been going through a really rough period at work this week It\'s my own fault for swapping my tampax for sand paper.\nIf I could have dinner with anyone, dead or alive... ...I would choose alive. -B.J. Novak-\nTwo guys walk into a bar. The third guy ducks.\nWhy can\'t Barbie get pregnant? Because Ken comes in a different box. Heyooooooo\nWhy was the musician arrested? He got in treble.\nDid you hear about the guy who blew his entire lottery winnings on a limousine? He had nothing left to chauffeur it.\nWhat do you do if a bird shits on your car? Don\'t ask her out again.\nHe was a real gentlemen and always opened the fridge door for me'

# %% [markdown]
# ## Using the inbuilt or available corpus for training

# %%
docs = """About the Program
What is the course fee for  Data Science Mentorship Program (DSMP 2023)
The course follows a monthly subscription model where you have to make monthly payments of Rs 799/month.
What is the total duration of the course?
The total duration of the course is 7 months. So the total course fee becomes 799*7 = Rs 5600(approx.)
What is the syllabus of the mentorship program?
We will be covering the following modules:
Python Fundamentals
Python libraries for Data Science
Data Analysis
SQL for Data Science
Maths for Machine Learning
ML Algorithms
Practical ML
MLOPs
Case studies
You can check the detailed syllabus here - https://learnwith.campusx.in/courses/CampusX-Data-Science-Mentorship-Program-637339afe4b0615a1bbed390
Will Deep Learning and NLP be a part of this program?
No, NLP and Deep Learning both are not a part of this program’s curriculum.
What if I miss a live session? Will I get a recording of the session?
Yes all our sessions are recorded, so even if you miss a session you can go back and watch the recording.
Where can I find the class schedule?
Checkout this google sheet to see month by month time table of the course - https://docs.google.com/spreadsheets/d/16OoTax_A6ORAeCg4emgexhqqPv3noQPYKU7RJ6ArOzk/edit?usp=sharing.
What is the time duration of all the live sessions?
Roughly, all the sessions last 2 hours.
What is the language spoken by the instructor during the sessions?
Hinglish
How will I be informed about the upcoming class?
You will get a mail from our side before every paid session once you become a paid user.
Can I do this course if I am from a non-tech background?
Yes, absolutely.
I am late, can I join the program in the middle?
Absolutely, you can join the program anytime.
If I join/pay in the middle, will I be able to see all the past lectures?
Yes, once you make the payment you will be able to see all the past content in your dashboard.
Where do I have to submit the task?
You don’t have to submit the task. We will provide you with the solutions, you have to self evaluate the task yourself.
Will we do case studies in the program?
Yes.
Where can we contact you?
You can mail us at nitish.campusx@gmail.com
Payment/Registration related questions
Where do we have to make our payments? Your YouTube channel or website?
You have to make all your monthly payments on our website. Here is the link for our website - https://learnwith.campusx.in/
Can we pay the entire amount of Rs 5600 all at once?
Unfortunately no, the program follows a monthly subscription model.
What is the validity of monthly subscription? Suppose if I pay on 15th Jan, then do I have to pay again on 1st Feb or 15th Feb
15th Feb. The validity period is 30 days from the day you make the payment. So essentially you can join anytime you don’t have to wait for a month to end.
What if I don’t like the course after making the payment. What is the refund policy?
You get a 7 days refund period from the day you have made the payment.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at nitish.campusx@gmail.com
Post registration queries
Till when can I view the paid videos on the website?
This one is tricky, so read carefully. You can watch the videos till your subscription is valid. Suppose you have purchased subscription on 21st Jan, you will be able to watch all the past paid sessions in the period of 21st Jan to 20th Feb. But after 21st Feb you will have to purchase the subscription again.
But once the course is over and you have paid us Rs 5600(or 7 installments of Rs 799) you will be able to watch the paid sessions till Aug 2024.
Why lifetime validity is not provided?
Because of the low course fee.
Where can I reach out in case of a doubt after the session?
You will have to fill a google form provided in your dashboard and our team will contact you for a 1 on 1 doubt clearance session
If I join the program late, can I still ask past week doubts?
Yes, just select past week doubt in the doubt clearance google form.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at nitish.campusx@gmai.com
Certificate and Placement Assistance related queries
What is the criteria to get the certificate?
There are 2 criterias:
You have to pay the entire fee of Rs 5600
You have to attempt all the course assessments.
I am joining late. How can I pay payment of the earlier months?
You will get a link to pay fee of earlier months in your dashboard once you pay for the current month.
I have read that Placement assistance is a part of this program. What comes under Placement assistance?
This is to clarify that Placement assistance does not mean Placement guarantee. So we dont guarantee you any jobs or for that matter even interview calls. So if you are planning to join this course just for placements, I am afraid you will be disappointed. Here is what comes under placement assistance
Portfolio Building sessions
Soft skill sessions
Sessions with industry mentors
Discussion on Job hunting strategies
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([docs])

# %%
dict = tokenizer.word_index

# %%
input_sequences = []

# Assuming docs is a string containing multiple sentences separated by newlines
for sentence in docs.split("\n"):
    # Tokenize the sentence and get the sequence of tokens
    sequence = tokenizer.texts_to_sequences([sentence])[0]
    n = len(sequence)
    for i in range(1, n):
        input_sequences.append(sequence[0:i+1])

# %%
max_length = max([len(sequence) for sequence in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
padded_list = pad_sequences(input_sequences, maxlen = max_length, padding="pre")

# %%
X = padded_list[:,:-1]

# %%
from tensorflow.keras.utils import to_categorical

# %%
y = padded_list[:,-1]
y = to_categorical(y,num_classes=len(dict)+1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Embedding

# %%
model = Sequential()
model.add(Embedding(283, 100, input_length=56))
model.add(LSTM(150))
model.add(Dense(283, activation='softmax'))

# %%
model.compile(loss="categorical_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 56, 100)           28300
#
#  lstm_8 (LSTM)               (None, 150)               150600
#
#  dense_4 (Dense)             (None, 283)               42733
#
# =================================================================
# Total params: 221633 (865.75 KB)
# Trainable params: 221633 (865.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 3s 56ms/step - loss: 5.4229 - accuracy: 0.0672
# Epoch 2/100
# 27/27 [==============================] - 1s 48ms/step - loss: 5.0968 - accuracy: 0.0776
# Epoch 3/100
# 27/27 [==============================] - 1s 47ms/step - loss: 5.0209 - accuracy: 0.0776
# Epoch 4/100
# 27/27 [==============================] - 1s 48ms/step - loss: 4.9909 - accuracy: 0.0776
# Epoch 5/100
# 27/27 [==============================] - 1s 48ms/step - loss: 4.9447 - accuracy: 0.0776
# Epoch 6/100
# 27/27 [==============================] - 1s 51ms/step - loss: 4.8756 - accuracy: 0.0776
# Epoch 7/100
# 27/27 [==============================] - 1s 46ms/step - loss: 4.7325 - accuracy: 0.0985
# Epoch 8/100
# 27/27 [==============================] - 1s 47ms/step - loss: 4.5200 - accuracy: 0.1460
# Epoch 9/100
# 27/27 [==============================] - 1s 47ms/step - loss: 4.2716 - accuracy: 0.1819
# Epoch 10/100
# 27/27 [==============================] - 1s 47ms/step - loss: 4.0196 - accuracy: 0.2051
# Epoch 11/100
# 27/27 [==============================] - 1s 46ms/step - loss: 3.7696 - accuracy: 0.2236
# Epoch 12/100
# 27/27 [==============================] - 1s 46ms/step - loss: 3.5400 - accuracy: 0.2619
# Epoch 13/100
# 27/27 [==============================] - 1s 47ms/step - loss: 3.3119 - accuracy: 0.2990
# Epoch 14/100
# 27/27 [==============================] - 1s 47ms/step - loss: 3.0973 - accuracy: 0.3360
# Epoch 15/100
# 27/27 [==============================] - 1s 49ms/step - loss: 2.8802 - accuracy: 0.3662
# Epoch 16/100
# 27/27 [==============================] - 1s 49ms/step - loss: 2.6857 - accuracy: 0.4021
# Epoch 17/100
# 27/27 [==============================] - 1s 49ms/step - loss: 2.5030 - accuracy: 0.4554
# Epoch 18/100
# 27/27 [==============================] - 1s 48ms/step - loss: 2.3141 - accuracy: 0.4844
# Epoch 19/100
# 27/27 [==============================] - 1s 49ms/step - loss: 2.1534 - accuracy: 0.5330
# Epoch 20/100
# 27/27 [==============================] - 1s 48ms/step - loss: 2.0077 - accuracy: 0.5504
# Epoch 21/100
# 27/27 [==============================] - 1s 49ms/step - loss: 1.8595 - accuracy: 0.5956
# Epoch 22/100
# 27/27 [==============================] - 1s 51ms/step - loss: 1.7299 - accuracy: 0.6315
# Epoch 23/100
# 27/27 [==============================] - 1s 50ms/step - loss: 1.6144 - accuracy: 0.6628
# Epoch 24/100
# 27/27 [==============================] - 1s 51ms/step - loss: 1.5011 - accuracy: 0.6929
# Epoch 25/100
# 27/27 [==============================] - 1s 52ms/step - loss: 1.3936 - accuracy: 0.7231
# Epoch 26/100
# 27/27 [==============================] - 1s 49ms/step - loss: 1.2917 - accuracy: 0.7590
# Epoch 27/100
# 27/27 [==============================] - 1s 48ms/step - loss: 1.2018 - accuracy: 0.7775
# Epoch 28/100
# 27/27 [==============================] - 1s 50ms/step - loss: 1.1296 - accuracy: 0.8007
# Epoch 29/100
# 27/27 [==============================] - 1s 49ms/step - loss: 1.0451 - accuracy: 0.8169
# Epoch 30/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.9776 - accuracy: 0.8424
# Epoch 31/100
# 27/27 [==============================] - 1s 46ms/step - loss: 0.9099 - accuracy: 0.8459
# Epoch 32/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.8491 - accuracy: 0.8714
# Epoch 33/100
# 27/27 [==============================] - 1s 50ms/step - loss: 0.7951 - accuracy: 0.8783
# Epoch 34/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.7458 - accuracy: 0.8911
# Epoch 35/100
# 27/27 [==============================] - 1s 47ms/step - loss: 0.6982 - accuracy: 0.8980
# Epoch 36/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.6588 - accuracy: 0.9061
# Epoch 37/100
# 27/27 [==============================] - 1s 47ms/step - loss: 0.6172 - accuracy: 0.9119
# Epoch 38/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.5841 - accuracy: 0.9166
# Epoch 39/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.5538 - accuracy: 0.9247
# Epoch 40/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.5189 - accuracy: 0.9235
# Epoch 41/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.4942 - accuracy: 0.9282
# Epoch 42/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.4692 - accuracy: 0.9351
# Epoch 43/100
# 27/27 [==============================] - 1s 50ms/step - loss: 0.4448 - accuracy: 0.9340
# Epoch 44/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.4229 - accuracy: 0.9421
# Epoch 45/100
# 27/27 [==============================] - 1s 47ms/step - loss: 0.4027 - accuracy: 0.9363
# Epoch 46/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.3841 - accuracy: 0.9421
# Epoch 47/100
# 27/27 [==============================] - 1s 47ms/step - loss: 0.3672 - accuracy: 0.9397
# Epoch 48/100
# 27/27 [==============================] - 1s 47ms/step - loss: 0.3502 - accuracy: 0.9397
# Epoch 49/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.3381 - accuracy: 0.9467
# Epoch 50/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.3216 - accuracy: 0.9444
# Epoch 51/100
# 27/27 [==============================] - 1s 50ms/step - loss: 0.3105 - accuracy: 0.9409
# Epoch 52/100
# 27/27 [==============================] - 1s 51ms/step - loss: 0.3009 - accuracy: 0.9455
# Epoch 53/100
# 27/27 [==============================] - 1s 50ms/step - loss: 0.2872 - accuracy: 0.9467
# Epoch 54/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.2788 - accuracy: 0.9432
# Epoch 55/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.2685 - accuracy: 0.9467
# Epoch 56/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.2609 - accuracy: 0.9444
# Epoch 57/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.2518 - accuracy: 0.9490
# Epoch 58/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.2427 - accuracy: 0.9502
# Epoch 59/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.2379 - accuracy: 0.9455
# Epoch 60/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.2329 - accuracy: 0.9490
# Epoch 61/100
# 27/27 [==============================] - 1s 51ms/step - loss: 0.2259 - accuracy: 0.9455
# Epoch 62/100
# 27/27 [==============================] - 1s 50ms/step - loss: 0.2195 - accuracy: 0.9421
# Epoch 63/100
# 27/27 [==============================] - 1s 51ms/step - loss: 0.2151 - accuracy: 0.9490
# Epoch 64/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.2085 - accuracy: 0.9467
# Epoch 65/100
# 27/27 [==============================] - 1s 47ms/step - loss: 0.2092 - accuracy: 0.9397
# Epoch 66/100
# 27/27 [==============================] - 1s 46ms/step - loss: 0.2000 - accuracy: 0.9490
# Epoch 67/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.1975 - accuracy: 0.9467
# Epoch 68/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.1909 - accuracy: 0.9490
# Epoch 69/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.1876 - accuracy: 0.9467
# Epoch 70/100
# 27/27 [==============================] - 1s 52ms/step - loss: 0.1850 - accuracy: 0.9467
# Epoch 71/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.1823 - accuracy: 0.9432
# Epoch 72/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.1794 - accuracy: 0.9490
# Epoch 73/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.1779 - accuracy: 0.9455
# Epoch 74/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.1723 - accuracy: 0.9409
# Epoch 75/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.1714 - accuracy: 0.9455
# Epoch 76/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.1681 - accuracy: 0.9467
# Epoch 77/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.1678 - accuracy: 0.9467
# Epoch 78/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.1629 - accuracy: 0.9502
# Epoch 79/100
# 27/27 [==============================] - 1s 51ms/step - loss: 0.1602 - accuracy: 0.9432
# Epoch 80/100
# 27/27 [==============================] - 1s 50ms/step - loss: 0.1589 - accuracy: 0.9432
# Epoch 81/100
# 27/27 [==============================] - 1s 50ms/step - loss: 0.1566 - accuracy: 0.9502
# Epoch 82/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.1539 - accuracy: 0.9467
# Epoch 83/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.1531 - accuracy: 0.9467
# Epoch 84/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.1519 - accuracy: 0.9479
# Epoch 85/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.1487 - accuracy: 0.9490
# Epoch 86/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.1477 - accuracy: 0.9490
# Epoch 87/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.1483 - accuracy: 0.9455
# Epoch 88/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.1440 - accuracy: 0.9479
# Epoch 89/100
# 27/27 [==============================] - 1s 50ms/step - loss: 0.1451 - accuracy: 0.9490
# Epoch 90/100
# 27/27 [==============================] - 1s 50ms/step - loss: 0.1425 - accuracy: 0.9455
# Epoch 91/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.1420 - accuracy: 0.9432
# Epoch 92/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.1421 - accuracy: 0.9386
# Epoch 93/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.1403 - accuracy: 0.9479
# Epoch 94/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.1380 - accuracy: 0.9432
# Epoch 95/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.1395 - accuracy: 0.9479
# Epoch 96/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.1373 - accuracy: 0.9432
# Epoch 97/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.1367 - accuracy: 0.9397
# Epoch 98/100
# 27/27 [==============================] - 1s 51ms/step - loss: 0.1355 - accuracy: 0.9432
# Epoch 99/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.1343 - accuracy: 0.9467
# Epoch 100/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.1343 - accuracy: 0.9467

# %%
import time
import numpy as np

# %%
text = "what is the fee"

# %%
for i in range(10):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 [==============================] - 0s 384ms/step
# what is the fee of
# 1/1 [==============================] - 0s 31ms/step
# what is the fee of the
# 1/1 [==============================] - 0s 30ms/step
# what is the fee of the mentorship
# 1/1 [==============================] - 0s 29ms/step
# what is the fee of the mentorship program
# 1/1 [==============================] - 0s 30ms/step
# what is the fee of the mentorship program dsmp
# 1/1 [==============================] - 0s 30ms/step
# what is the fee of the mentorship program dsmp 2023
# 1/1 [==============================] - 0s 29ms/step
# what is the fee of the mentorship program dsmp 2023 2023
# 1/1 [==============================] - 0s 29ms/step
# what is the fee of the mentorship program dsmp 2023 2023 2023
# 1/1 [==============================] - 0s 29ms/step
# what is the fee of the mentorship program dsmp 2023 2023 2023 once
# 1/1 [==============================] - 0s 30ms/step
# what is the fee of the mentorship program dsmp 2023 2023 2023 once you
